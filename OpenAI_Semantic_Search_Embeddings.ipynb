# %% [markdown]
# <a href="https://colab.research.google.com/github/rodrigoprieto/openai-semantic-search/blob/main/OpenAI_Semantic_Search_Embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Incrustaciones de palabras de OpenAI, búsqueda semántica
#
# Las incrustaciones de palabras son una forma de representar palabras y frases como vectores. Se pueden utilizar para una variedad de tareas, incluyendo la búsqueda semántica, la detección de anomalías y la clasificación.
#
# En este tutorial, aprenderemos cómo implementar la búsqueda semántica utilizando las incrustaciones de OpenAI.

# %%
# !pip install openai -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.3/269.3 kB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 14.6 MB/s eta 0:00:00

# %%
import openai
import pandas as pd
import numpy as np
from getpass import getpass

openai.api_key = getpass()
# Out:
# ··········

# %% [markdown]
# # Leer archivo de datos que contiene palabras
# Ahora que hemos configurado OpenAI, comencemos con un archivo CSV simple con palabras familiares.

# %%
df = pd.read_csv('words.csv')
print(df)
# Out:
#                     texto
# 0                    rojo
# 1                   papas
# 2                 gaseosa
# 3                   queso
# 4                    agua
# 5                    azul
# 6               crujiente
# 7             hamburguesa
# 8                    café
# 9                   verde
# 10                  leche
# 11              medialuna
# 12               amarillo
# 13              chocolate
# 14           papas fritas
# 15         café con leche
# 16                 pastel
# 17                 marrón
# 18  hamburguesa con queso
# 19               espresso
# 20        pastel de queso
# 21                  negro
# 22           efervescente
# 23              carbonato
# 24                 banana

# %%
from openai.embeddings_utils import get_embedding

df['embedding'] = df['texto'].apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))
df.to_csv('word_embeddings.csv')

# %% [markdown]
# # Búsqueda semántica
#
# Ahora que tenemos nuestras incrustaciones de palabras almacenadas, carguemoslas en un nuevo dataframe y utilicémoslas para la búsqueda semántica. Como la "incrustación" en el CSV se almacena como una cadena, usaremos apply() para interpretar esta cadena como código de Python y convertirla en un array de numpy para poder realizar cálculos sobre ella.

# %%
df = pd.read_csv('word_embeddings.csv')
df['embedding'] = df['embedding'].apply(eval).apply(np.array)
df
# Out:
#     Unnamed: 0                  texto  \
# 0            0                   rojo
# 1            1                  papas
# 2            2                gaseosa
# 3            3                  queso
# 4            4                   agua
# 5            5                   azul
# 6            6              crujiente
# 7            7            hamburguesa
# 8            8                   café
# 9            9                  verde
# 10          10                  leche
# 11          11              medialuna
# 12          12               amarillo
# 13          13              chocolate
# 14          14           papas fritas
# 15          15         café con leche
# 16          16                 pastel
# 17          17                 marrón
# 18          18  hamburguesa con queso
# 19          19               espresso
# 20          20        pastel de queso
# 21          21                  negro
# 22          22           efervescente
# 23          23              carbonato
# 24          24                 banana
#
#                                             embedding
# 0   [-0.00825595110654831, -0.020036915317177773, ...
# 1   [0.014665703289210796, -0.009138461202383041, ...
# 2   [-0.008838117122650146, 0.006368149071931839, ...
# 3   [-0.006237938068807125, -0.007689959369599819,...
# 4   [0.0070021492429077625, -0.011482452042400837,...
# 5   [-0.010242876596748829, -0.010774284601211548,...
# 6   [-0.022419488057494164, -0.0037925182841718197...
# 7   [-0.01841752789914608, -0.004099969286471605, ...
# 8   [-0.024081707000732422, -0.02313094213604927, ...
# 9   [-0.013723647221922874, 0.0014768337132409215,...
# 10  [-0.006822008639574051, 0.004758767317980528, ...
# 11  [-0.01110006682574749, 0.011255833320319653, 0...
# 12  [-0.012129882350564003, -0.018191467970609665,...
# 13  [0.0015315973432734609, -0.012976923026144505,...
# 14  [0.016551895067095757, -0.006924640852957964, ...
# 15  [-0.011370548978447914, 0.004442431963980198, ...
# 16  [-0.00509793683886528, -0.012015840969979763, ...
# 17  [-0.014953788369894028, -0.015329251065850258,...
# 18  [-0.004712946712970734, 0.005816323217004538, ...
# 19  [-0.02250547707080841, -0.012807613238692284, ...
# 20  [0.0006732486071996391, -0.0023420194629579782...
# 21  [-0.021674923598766327, -0.023495061323046684,...
# 22  [-0.0315360501408577, -0.0027484174352139235, ...
# 23  [-0.0032687289640307426, -0.002615972189232707...
# 24  [-0.013975119218230247, -0.03290277719497681, ...

# %% [markdown]
# # Búsqueda por similitud
# Ahora pidamos un término de búsqueda que no esté en el dataframe. Usaremos incrustaciones de palabras para realizar una búsqueda semántica de las palabras que sean más similares a la palabra que ingresamos.

# %%
search_term = input('Ingrese un término de búsqueda: ')
# Out:
# Ingrese un término de búsqueda: quiero hacer un licuado de banana

# %% [markdown]
# Ahora que tenemos un término de búsqueda, calculemos el vector para ese término de búsqueda utilizando la función get_embedding de OpenAI.

# %%
# semantic search
search_term_vector = get_embedding(search_term, engine="text-embedding-ada-002")
search_term_vector
# Out:
# [-0.03575626760721207,
#  -0.008524334989488125,
#  0.0007497076294384897,
#  -0.0010655418736860156,
#  0.022357238456606865,
#  -0.007152529899030924,
#  -0.017291128635406494,
#  0.007618305739015341,
#  -0.011197760701179504,
#  -0.030115915462374687,
#  0.007809720002114773,
#  0.017801567912101746,
#  -0.018962817266583443,
#  0.009341037832200527,
#  -0.010081174783408642,
#  0.012518522329628468,
#  0.026721494272351265,
#  -0.020889725536108017,
#  0.016614796593785286,
#  -0.006922832224518061,
#  -0.01353940088301897,
#  0.010604375042021275,
#  0.03631775081157684,
#  -0.024666976183652878,
#  -0.013807381503283978,
#  0.001484261592850089,
#  0.011102053336799145,
#  -0.005554216913878918,
#  0.010425721295177937,
#  0.013679771684110165,
#  0.03835950791835785,
#  -0.0019556202460080385,
#  0.012952395714819431,
#  -0.009500550106167793,
#  -0.019868846982717514,
#  -0.018567226827144623,
#  -0.010483145713806152,
#  0.005359611939638853,
#  0.012295205146074295,
#  -0.010668179951608181,
#  0.008154266513884068,
#  -0.007254617754369974,
#  0.01402431819587946,
#  -0.007452412974089384,
#  -0.015912942588329315,
#  0.019269080832600594,
#  -0.02728297747671604,
#  -0.010304491966962814,
#  -0.034556735306978226,
#  0.0020593032240867615,
#  0.018988339230418205,
#  -0.001887030084617436,
#  -0.030753962695598602,
#  -0.003646450350061059,
#  -0.007241856772452593,
#  0.0002514311927370727,
#  -0.0021294886246323586,
#  -0.010706462897360325,
#  0.0005028623854741454,
#  0.009838716126978397,
# Una vez que tenemos un vector que representa esa palabra, podemos ver qué tan similar es a otras palabras en nuestro dataframe calculando la similitud coseno del vector de palabra de nuestro término de búsqueda con el embeddings de las palabras en nuestro dataframe.

# %%
from openai.embeddings_utils import cosine_similarity

df["similarities"] = df['embedding'].apply(lambda x: cosine_similarity(x, search_term_vector))

df
# Out:
#     Unnamed: 0                  texto  \
# 0            0                   rojo
# 1            1                  papas
# 2            2                gaseosa
# 3            3                  queso
# 4            4                   agua
# 5            5                   azul
# 6            6              crujiente
# 7            7            hamburguesa
# 8            8                   café
# 9            9                  verde
# 10          10                  leche
# 11          11              medialuna
# 12          12               amarillo
# 13          13              chocolate
# 14          14           papas fritas
# 15          15         café con leche
# 16          16                 pastel
# 17          17                 marrón
# 18          18  hamburguesa con queso
# 19          19               espresso
# 20          20        pastel de queso
# 21          21                  negro
# 22          22           efervescente
# 23          23              carbonato
# 24          24                 banana
#
#                                             embedding  similarities
# 0   [-0.00825595110654831, -0.020036915317177773, ...      0.786708
# 1   [0.014665703289210796, -0.009138461202383041, ...      0.768289
# 2   [-0.008838117122650146, 0.006368149071931839, ...      0.784348
# 3   [-0.006237938068807125, -0.007689959369599819,...      0.789680
# 4   [0.0070021492429077625, -0.011482452042400837,...      0.774537
# 5   [-0.010242876596748829, -0.010774284601211548,...      0.781585
# 6   [-0.022419488057494164, -0.0037925182841718197...      0.809524
# 7   [-0.01841752789914608, -0.004099969286471605, ...      0.812533
# 8   [-0.024081707000732422, -0.02313094213604927, ...      0.769620
# 9   [-0.013723647221922874, 0.0014768337132409215,...      0.788589
# 10  [-0.006822008639574051, 0.004758767317980528, ...      0.828324
# 11  [-0.01110006682574749, 0.011255833320319653, 0...      0.775054
# 12  [-0.012129882350564003, -0.018191467970609665,...      0.771522
# 13  [0.0015315973432734609, -0.012976923026144505,...      0.762739
# 14  [0.016551895067095757, -0.006924640852957964, ...      0.789667
# 15  [-0.011370548978447914, 0.004442431963980198, ...      0.826272
# 16  [-0.00509793683886528, -0.012015840969979763, ...      0.755781
# 17  [-0.014953788369894028, -0.015329251065850258,...      0.775833
# 18  [-0.004712946712970734, 0.005816323217004538, ...      0.807063
# 19  [-0.02250547707080841, -0.012807613238692284, ...      0.780204
# 20  [0.0006732486071996391, -0.0023420194629579782...      0.784328
# 21  [-0.021674923598766327, -0.023495061323046684,...      0.761709
# 22  [-0.0315360501408577, -0.0027484174352139235, ...      0.786017
# 23  [-0.0032687289640307426, -0.002615972189232707...      0.754088
# 24  [-0.013975119218230247, -0.03290277719497681, ...      0.829629

# %% [markdown]
# # Ordenando por similitud
# Ahora que hemos calculado las similitudes para cada término en nuestro dataframe, simplemente ordenamos los valores de similitud para encontrar los términos que son más similares al término que buscamos.

# %%
df.sort_values("similarities", ascending=False).head(20)
# Out:
#     Unnamed: 0                  texto  \
# 24          24                 banana
# 10          10                  leche
# 15          15         café con leche
# 7            7            hamburguesa
# 6            6              crujiente
# 18          18  hamburguesa con queso
# 3            3                  queso
# 14          14           papas fritas
# 9            9                  verde
# 0            0                   rojo
# 22          22           efervescente
# 2            2                gaseosa
# 20          20        pastel de queso
# 5            5                   azul
# 19          19               espresso
# 17          17                 marrón
# 11          11              medialuna
# 4            4                   agua
# 12          12               amarillo
# 8            8                   café
#
#                                             embedding  similarities
# 24  [-0.013975119218230247, -0.03290277719497681, ...      0.829629
# 10  [-0.006822008639574051, 0.004758767317980528, ...      0.828324
# 15  [-0.011370548978447914, 0.004442431963980198, ...      0.826272
# 7   [-0.01841752789914608, -0.004099969286471605, ...      0.812533
# 6   [-0.022419488057494164, -0.0037925182841718197...      0.809524
# 18  [-0.004712946712970734, 0.005816323217004538, ...      0.807063
# 3   [-0.006237938068807125, -0.007689959369599819,...      0.789680
# 14  [0.016551895067095757, -0.006924640852957964, ...      0.789667
# 9   [-0.013723647221922874, 0.0014768337132409215,...      0.788589
# 0   [-0.00825595110654831, -0.020036915317177773, ...      0.786708
# 22  [-0.0315360501408577, -0.0027484174352139235, ...      0.786017
# 2   [-0.008838117122650146, 0.006368149071931839, ...      0.784348
# 20  [0.0006732486071996391, -0.0023420194629579782...      0.784328
# 5   [-0.010242876596748829, -0.010774284601211548,...      0.781585
# 19  [-0.02250547707080841, -0.012807613238692284, ...      0.780204
# 17  [-0.014953788369894028, -0.015329251065850258,...      0.775833
# 11  [-0.01110006682574749, 0.011255833320319653, 0...      0.775054
# 4   [0.0070021492429077625, -0.011482452042400837,...      0.774537
# 12  [-0.012129882350564003, -0.018191467970609665,...      0.771522
# 8   [-0.024081707000732422, -0.02313094213604927, ...      0.769620

# %% [markdown]
# # Sumando palabras
# Lo que es aún más interesante es que podemos sumar vectores de palabras. ¿Qué sucede cuando sumamos los vectores de "hamburguesa" y "queso", y luego buscamos el vector de palabras más similar a "hamburguesa + queso"? Haremos una copia del dataframe original y lo llamaremos food_df. Trabajaremos con esta copia. Intentemos sumar las palabras. Sumemos "hamburguesa" y "queso" y guardemos los resultados en hamburger_cheese_vector.

# %%
food_df = df.copy()

hamburguer_vector = food_df['embedding'][7]
cheese_vector = food_df['embedding'][3]

hamburger_cheese_vector = hamburguer_vector + cheese_vector
hamburger_cheese_vector
# Out:
# array([-0.02465547, -0.01178993,  0.01182726, ...,  0.00276016,
#         0.03109807, -0.01253029])

# %% [markdown]
# Ahora encontremos las palabras más similares a "hamburguesa + queso". Si nunca ha hecho esto antes, es bastante sorprendente que se puedan sumar palabras de esta manera y encontrar palabras similares utilizando números.

# %%
food_df["similarities"] = food_df['embedding'].apply(lambda x: cosine_similarity(x, hamburger_cheese_vector))
food_df.sort_values("similarities", ascending=False)
# Out:
#     Unnamed: 0                  texto  \
# 7            7            hamburguesa
# 3            3                  queso
# 18          18  hamburguesa con queso
# 20          20        pastel de queso
# 10          10                  leche
# 14          14           papas fritas
# 0            0                   rojo
# 2            2                gaseosa
# 15          15         café con leche
# 9            9                  verde
# 8            8                   café
# 6            6              crujiente
# 19          19               espresso
# 21          21                  negro
# 5            5                   azul
# 4            4                   agua
# 22          22           efervescente
# 13          13              chocolate
# 1            1                  papas
# 17          17                 marrón
# 12          12               amarillo
# 24          24                 banana
# 11          11              medialuna
# 16          16                 pastel
# 23          23              carbonato
#
#                                             embedding  similarities
# 7   [-0.01841752789914608, -0.004099969286471605, ...      0.955733
# 3   [-0.006237938068807125, -0.007689959369599819,...      0.955733
# 18  [-0.004712946712970734, 0.005816323217004538, ...      0.949004
# 20  [0.0006732486071996391, -0.0023420194629579782...      0.891752
# 10  [-0.006822008639574051, 0.004758767317980528, ...      0.889970
# 14  [0.016551895067095757, -0.006924640852957964, ...      0.884525
# 0   [-0.00825595110654831, -0.020036915317177773, ...      0.863373
# 2   [-0.008838117122650146, 0.006368149071931839, ...      0.861929
# 15  [-0.011370548978447914, 0.004442431963980198, ...      0.860943
# 9   [-0.013723647221922874, 0.0014768337132409215,...      0.857358
# 8   [-0.024081707000732422, -0.02313094213604927, ...      0.856666
# 6   [-0.022419488057494164, -0.0037925182841718197...      0.854660
# 19  [-0.02250547707080841, -0.012807613238692284, ...      0.854622
# 21  [-0.021674923598766327, -0.023495061323046684,...      0.851836
# 5   [-0.010242876596748829, -0.010774284601211548,...      0.847938
# 4   [0.0070021492429077625, -0.011482452042400837,...      0.847850
# 22  [-0.0315360501408577, -0.0027484174352139235, ...      0.847654
# 13  [0.0015315973432734609, -0.012976923026144505,...      0.846018
# 1   [0.014665703289210796, -0.009138461202383041, ...      0.845595
# 17  [-0.014953788369894028, -0.015329251065850258,...      0.843184
# 12  [-0.012129882350564003, -0.018191467970609665,...      0.842309
# 24  [-0.013975119218230247, -0.03290277719497681, ...      0.840008
# 11  [-0.01110006682574749, 0.011255833320319653, 0...      0.832923
# 16  [-0.00509793683886528, -0.012015840969979763, ...      0.832120
# 23  [-0.0032687289640307426, -0.002615972189232707...      0.820945

# %% [markdown]
# # 🤓 PARA NERDS: Calculando la similitud coseno
#
# Utilizamos la función de similitud coseno, pero ¿cómo funciona realmente? La similitud coseno es simplemente el cálculo de la similitud entre dos vectores. Existe una ecuación matemática para calcular el ángulo entre dos vectores.
#
# ![](https://drive.google.com/uc?export=view&id=1cehvtx7LKuFeq_LqfnLi-gzIz1D1wSf9)

# %%
v1 = np.array([1,2,3])
v2 = np.array([4,5,6])

# (1 * 4) + (2 * 5) + (3 * 6)
dot_product = np.dot(v1, v2)
dot_product
# Out:
# 32

# %%
# square root of (1^2 + 2^2 + 3^2) = square root of (1+4+9) = square root of 14
np.linalg.norm(v1)
# Out:
# 3.7416573867739413

# %%
# square root of (4^2 + 5^2 + 6^2) = square root of (16+25+36) = square root of 14
np.linalg.norm(v2)
# Out:
# 8.774964387392123

# %%
magnitude = np.linalg.norm(v1) * np.linalg.norm(v2)
magnitude
# Out:
# 32.83291031876401

# %%
dot_product / magnitude
# Out:
# 0.9746318461970762

# %%
from scipy import spatial

result = 1 - spatial.distance.cosine(v1, v2)

result
# Out:
# 0.9746318461970761
